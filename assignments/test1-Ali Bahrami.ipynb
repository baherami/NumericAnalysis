# %% [markdown]
# # Mid term test
# Introduction to Numerical Problem Solving, Spring 2017
# 15.3.2017, Ali Bahrami
#
# Helsinki Metropolia University of Applied Sciences

# %% [markdown]
# General import for all the questions.

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import *
from numpy import *
from scipy.misc import factorial

# %% [markdown]
# # 1.a

# %%
def approx_log(x,iterat):
    n=1
    sumx=0
    sign=1.0
    while(n<(iterat+1)):
        sumx=sumx+ (sign* (1/n)*((x-1)**n) )
        sign=sign * (-1)
        n+=1
    return sumx
x=arange(-5,5,0.01)
y=approx_log(x,5)

figure()
plot(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 1.b

# %%
x=2.0
n=5
true_value =log(x)
approximation= approx_log(x,n)
Et=true_value -approximation
relative_true_error=Et/true_value
print("aprox=",approximation,"true value",true_value)

print("true error is",Et)
print("relative true error is",relative_true_error)
# Out:
# aprox= 0.7833333333333332 true value 0.69314718056
# true error is -0.0901861527734
# relative true error is -0.130111115363

# %% [markdown]
# # 1.c

# %%
def approx_log2(x,es):
    n=1
    sumx=0.0
    appx=0.0
    ea=1
    prevsumx=0.0
    sign=1.0
    while True:
        appx=(sign* (1/n)*((x-1)**n))
        sign=sign * -1
        prevsumx=sumx
        sumx=prevsumx+appx 
        ea=abs((sumx - prevsumx)/sumx) *100
        n=n+1
        if(n>100000) or (ea<=es):
            break
    print("ea=",ea,"es=",es,"log(2.0)=",log(x),"approximation of log(2.0)=",sumx)
    return n

n=3
es=(0.5*10**(2-n))
x=2.0
print("number of terms needed,",approx_log2(x,es))
# Out:
# ea= 0.04999426242696775 es= 0.05 log(2.0)= 0.69314718056 approximation of log(2.0)= 0.6933204607488206
# number of terms needed, 2886

# %% [markdown]
# # 2.a

# %%
def f(x):
    return 10.0 * exp (-(x-4.15)**2) *cos(6.0 *pi* x)

# %%
x=arange(0,8,0.01)
y = f(x)
figure()
plot(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x=arange(3.5,4.5,0.001)
y = f(x)
figure()
plot(x,y)
xlim([3.8,4.4])
ylim([8,10])
grid()
print(f(3.99),f(4.00),f(4.01))
print("for x=4.00 we have y max =",f(4.00))
# Out:
# <img src="data:image/png;base64,..." width="640">
# 9.57459843811 9.77751237193 9.63221871672
# for x=4.00 we have y max = 9.77751237193

# %% [markdown]
# # 2.b

# %%
x=arange(0,8,0.01)

y1 = f(x)
y2 = (x-x) + 5.0
figure()
plot(x,y1)
plot(x,y2,'r')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x=arange(0,8,0.01)
y1 = f(x)
y2 = (x-x) + 5.0
figure()
plot(x,y1)
plot(x,y2,'r')
xlim([4.0,6.0])
grid()
print("for x=5.0 y=",f(5.0))
# Out:
# <img src="data:image/png;base64,..." width="640">
# for x=5.0 y= 4.85536895154
# so x=

# %%
x=arange(0,8,0.01)
y1 = f(x)
y2 = (x-x) + 5.0
figure()
plot(x,y1)
plot(x,y2,'r')
xlim([4.50,4.75])
grid()
print("for x=4.71 y=",f(4.71))
# Out:
# <img src="data:image/png;base64,..." width="640">
# for x=4.71 y= 5.00274756438

# %% [markdown]
# # 2,b

# %%
x=arange(3.8,4.40,0.001)
y = f(x)
figure()
plot(x,y)
ylim([7.5,10])
grid()
plot(4.0,f(4.0),'o')
print(f(4.0))
# Out:
# <img src="data:image/png;base64,..." width="640">
# 9.77751237193

# %% [markdown]
# # 2.c

# %%
x=arange(4.0,5.0,0.001)
y = f(x)
figure()
plot(x,y)
grid()
xlim([4.150,4.175])
plot(4.165,f(4.165),'o')
print(f(4.165))
# Out:
# <img src="data:image/png;base64,..." width="640">
# -9.99281696688

# %% [markdown]
# # 3

# %%
from scipy.linalg import solve

# %%
p_r=1 / (2)**(1/2)
n_r= -1 * p_r
A = array([[-1,1,n_r,0,0,0],
           [0,0,p_r,1,0,0],
           [0,-1,0,0,n_r,0],
           [0,0,0,0,p_r,0],
           [0,0,0,0,p_r,1],
           [0,0,0,-1,n_r,0]
          ])
b= array([0,18,0,12,0,0])
p=solve(A,b)
print(p)
# Out:
# [-42.         -12.          42.42640687 -12.          16.97056275 -12.        ]

# %%
# Out:
# 4.858667061569122e-06
