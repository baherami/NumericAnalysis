# %% [markdown]
# # Assignment 06
#
#  Introduction to Numerical Problem Solving, Spring 2017
#
#  24.3.2017, Ali Bahrami
#
#  Helsinki Metropolia University of Applied Sciences

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import *
from numpy import *
from numpy.random import randn
from scipy.linalg import solve

# %% [markdown]
# ## 1. a
# Consider $T_1$, $T_2$, $T_3$ and  $a$ as the variables. There are four equations and four variables so the problem can have a solution.
# The variable matrix contains a last element which is $a$.

# %%
g = 9.81
theta = 45.0
m=array( [10,4,5,6.0])
u=array([0.25,0.30,0.20,1])
b=sin(theta)- cos(theta)*u
b[3]=-1.0
b=b*g*m
A=array([[1,0,0,m[0]],
         [-1,1,0,m[1]],
         [0,-1,1,m[2]],
         [0,0,-1,m[3]],
        ])
T = solve(A, b)
print("T1={0:.2f},T2={1:.2f},T3={2:.2f},a={3:.2f}".format(T[0],T[1],T[2],T[3]))
# Out:
# T1=40.38,T2=55.50,T3=76.98,a=3.02

# %% [markdown]
# # 1.b
# If system is stable,there is no move and $a=0$.

# %%
def getAcceleration(theta):
    g = 9.81
    theta = theta
    m=array( [10,4,5,6.0])
    u=array([0.25,0.30,0.20,1])
    b=sin(theta)- cos(theta)*u
    b[3]=-1.0
    b=b*g*m
    A=array([[1,0,0,m[0]],
         [-1,1,0,m[1]],
         [0,-1,1,m[2]],
         [0,0,-1,m[3]],
        ])
    T = solve(A, b)
    print("T1={0:.2f},T2={1:.2f},T3={2:.2f},a={3:.2f}".format(T[0],T[1],T[2],T[3]))
    return T[3]

theta=45
a=getAcceleration(theta)

figure('Problem 1.b')

plot(theta,a,'go')

theta=10
a=getAcceleration(theta)
plot(theta,a,'go')

theta=80
a=getAcceleration(theta)
plot(theta,a,'go')

axhline(y = 0, xmin = 0, xmax = 100, color = 'r')
axvline(x = 50, ymin = -3, ymax = 3, color = 'r')
grid()
xlabel(r"${\Theta}$")
ylabel('a')
show()
# Out:
# T1=40.38,T2=55.50,T3=76.98,a=3.02
# <img src="data:image/png;base64,..." width="640">
# T1=15.84,T2=23.82,T3=29.68,a=-4.86
# T1=0.82,T2=1.36,T3=1.49,a=-9.56

# %% [markdown]
# As we can see different values give different a
# Now we try to define a function to check all 0 to 360 degrees.

# %%
def getAcceleration(theta):
    g = 9.81
    theta = theta
    m=array( [10,4,5,6.0])
    u=array([0.25,0.30,0.20,1])
    b=sin(theta)- cos(theta)*u
    b[3]=-1.0
    b=b*g*m
    A=array([[1,0,0,m[0]],
         [-1,1,0,m[1]],
         [0,-1,1,m[2]],
         [0,0,-1,m[3]],
        ])
    T = solve(A, b)
    #print("T1={0:.2f},T2={1:.2f},T3={2:.2f},a={3:.2f}".format(T[0],T[1],T[2],T[3]))
    return T[3]


figure('Problem 1.b.1')

for i in range(0,360):
    theta=i
    a=getAcceleration(theta)
    plot(theta,a,'go')
    


axhline(y = 0, xmin = 0, xmax = 100, color = 'r')
axvline(x = 50, ymin = -3, ymax = 3, color = 'r')
grid()
xlabel(r"${\Theta}$")
ylabel('a')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Now we try to narrow the result by the condition of   -0.09<a<0.09 as it will be an accepted result for a=0.0 $m/s^2$

# %%
figure('Problem 1.b.2')

for i in range(0,360):
    theta=i
    a=getAcceleration(theta)
    if(a<0.09)and(a>-0.09):
        plot(theta,a,'go')
        print("Theta={0:.2f},a={1:.2f}".format(theta,a))

    


axhline(y = 0, xmin = 0, xmax = 100, color = 'r')
axvline(x = 50, ymin = -3, ymax = 3, color = 'r')
grid()
xlabel(r"${\Theta}$")
ylabel('a')
show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# Theta=179.00,a=0.01
# Theta=321.00,a=0.03

# %% [markdown]
# There are two places where a is less than 0.09
